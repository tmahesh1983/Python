# %%
# !pip install pandas
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gapminder.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe(include='all')
# Out:
#             country        year    population continent     life_exp  \
# count          1704  1704.00000  1.704000e+03      1704  1704.000000
# unique          142         NaN           NaN         5          NaN
# top     Afghanistan         NaN           NaN    Africa          NaN
# freq             12         NaN           NaN       624          NaN
# mean            NaN  1979.50000  2.960121e+07       NaN    59.474439
# std             NaN    17.26533  1.061579e+08       NaN    12.917107
# min             NaN  1952.00000  6.001100e+04       NaN    23.599000
# 25%             NaN  1965.75000  2.793664e+06       NaN    48.198000
# 50%             NaN  1979.50000  7.023596e+06       NaN    60.712500
# 75%             NaN  1993.25000  1.958522e+07       NaN    70.845500
# max             NaN  2007.00000  1.318683e+09       NaN    82.603000
#
#               gdp_cap
# count     1704.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
  df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].nunique()
# Out:
# 142

# %%
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df['country'].value_counts()[0:30]
# Out:
# Afghanistan    12
# Pakistan       12
# New Zealand    12
# Nicaragua      12
# Niger          12
# Nigeria        12
# Norway         12
# Oman           12
# Panama         12
# Nepal          12
# Paraguay       12
# Peru           12
# Philippines    12
# Poland         12
# Portugal       12
# Puerto Rico    12
# Netherlands    12
# Namibia        12
# Romania        12
# Mali           12
# Lesotho        12
# Liberia        12
# Libya          12
# Madagascar     12
# Malawi         12
# Malaysia       12
# Mauritania     12
# Myanmar        12
# Mauritius      12
# Mexico         12
# Name: country, dtype: int64

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.rename(columns={'country':'COUNTRY'})
# Out:
#           COUNTRY  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={'country':'COUNTRY'}, inplace=True)

# %%
df
# Out:
#           COUNTRY  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({'COUNTRY':'country'}, inplace=True, axis=1)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('continent', axis=1, inplace=True)
df
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# ##  Adding new column

# %%
df['new'] = df['life_exp'] + df['year']
df
# Out:
#           country  year  population  life_exp     gdp_cap       new
# 0     Afghanistan  1952     8425333    28.801  779.445314  1980.801
# 1     Afghanistan  1957     9240934    30.332  820.853030  1987.332
# 2     Afghanistan  1962    10267083    31.997  853.100710  1993.997
# 3     Afghanistan  1967    11537966    34.020  836.197138  2001.020
# 4     Afghanistan  1972    13079460    36.088  739.981106  2008.088
# ...           ...   ...         ...       ...         ...       ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  2049.351
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  2052.377
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  2043.809
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  2041.989
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  2050.487
#
# [1704 rows x 6 columns]

# %%
df['new2'] = 100
df
# Out:
#           country  year  population  life_exp     gdp_cap       new  new2
# 0     Afghanistan  1952     8425333    28.801  779.445314  1980.801   100
# 1     Afghanistan  1957     9240934    30.332  820.853030  1987.332   100
# 2     Afghanistan  1962    10267083    31.997  853.100710  1993.997   100
# 3     Afghanistan  1967    11537966    34.020  836.197138  2001.020   100
# 4     Afghanistan  1972    13079460    36.088  739.981106  2008.088   100
# ...           ...   ...         ...       ...         ...       ...   ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  2049.351   100
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  2052.377   100
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  2043.809   100
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  2041.989   100
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  2050.487   100
#
# [1704 rows x 7 columns]

# %%
df['new_3'] = np.random.randint(1, 250, size=1704)
df
# Out:
#           country  year  population  life_exp     gdp_cap       new  new2  \
# 0     Afghanistan  1952     8425333    28.801  779.445314  1980.801   100
# 1     Afghanistan  1957     9240934    30.332  820.853030  1987.332   100
# 2     Afghanistan  1962    10267083    31.997  853.100710  1993.997   100
# 3     Afghanistan  1967    11537966    34.020  836.197138  2001.020   100
# 4     Afghanistan  1972    13079460    36.088  739.981106  2008.088   100
# ...           ...   ...         ...       ...         ...       ...   ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  2049.351   100
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  2052.377   100
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  2043.809   100
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  2041.989   100
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  2050.487   100
#
#       new_3
# 0        98
# 1        16
# 2        65
# 3       236
# ...

# %% [markdown]
# ## Insert new column at specified location

# %%
df.insert(5, 'new_column', 2001)
df
# Out:
#           country  year  population  life_exp     gdp_cap  new_column  \
# 0     Afghanistan  1952     8425333    28.801  779.445314        2001
# 1     Afghanistan  1957     9240934    30.332  820.853030        2001
# 2     Afghanistan  1962    10267083    31.997  853.100710        2001
# 3     Afghanistan  1967    11537966    34.020  836.197138        2001
# 4     Afghanistan  1972    13079460    36.088  739.981106        2001
# ...           ...   ...         ...       ...         ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306        2001
# 1700     Zimbabwe  1992    10704340    60.377  693.420786        2001
# 1701     Zimbabwe  1997    11404948    46.809  792.449960        2001
# 1702     Zimbabwe  2002    11926563    39.989  672.038623        2001
# 1703     Zimbabwe  2007    12311143    43.487  469.709298        2001
#
#            new  new2  new_3
# 0     1980.801   100     98
# 1     1987.332   100     16
# 2     1993.997   100     65
# ...

# %% [markdown]
# ## Drop columns

# %%
df.drop(columns=['new_column','new'], inplace=True)
df
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.drop(columns=df.columns[-2:], inplace=True)
df
# Out:
#           country  year  population  life_exp     gdp_cap  new_column  \
# 0     Afghanistan  1952     8425333    28.801  779.445314        2001
# 1     Afghanistan  1957     9240934    30.332  820.853030        2001
# 2     Afghanistan  1962    10267083    31.997  853.100710        2001
# 3     Afghanistan  1967    11537966    34.020  836.197138        2001
# 4     Afghanistan  1972    13079460    36.088  739.981106        2001
# ...           ...   ...         ...       ...         ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306        2001
# 1700     Zimbabwe  1992    10704340    60.377  693.420786        2001
# 1701     Zimbabwe  1997    11404948    46.809  792.449960        2001
# 1702     Zimbabwe  2002    11926563    39.989  672.038623        2001
# 1703     Zimbabwe  2007    12311143    43.487  469.709298        2001
#
#            new
# 0     1980.801
# 1     1987.332
# 2     1993.997
# 3     2001.020
# 4     2008.088
# ...        ...
# ...

# %%
df
# Out:
#           country  year  population  life_exp     gdp_cap  new_column  \
# 0     Afghanistan  1952     8425333    28.801  779.445314        2001
# 1     Afghanistan  1957     9240934    30.332  820.853030        2001
# 2     Afghanistan  1962    10267083    31.997  853.100710        2001
# 3     Afghanistan  1967    11537966    34.020  836.197138        2001
# 4     Afghanistan  1972    13079460    36.088  739.981106        2001
# ...           ...   ...         ...       ...         ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306        2001
# 1700     Zimbabwe  1992    10704340    60.377  693.420786        2001
# 1701     Zimbabwe  1997    11404948    46.809  792.449960        2001
# 1702     Zimbabwe  2002    11926563    39.989  672.038623        2001
# 1703     Zimbabwe  2007    12311143    43.487  469.709298        2001
#
#            new
# 0     1980.801
# 1     1987.332
# 2     1993.997
# 3     2001.020
# 4     2008.088
# ...        ...
# ...

# %% [markdown]
# ## Working with Rows

# %%
df.head()
# Out:
#        country  year  population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
ser = df['country']
ser
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
ser[3]
# Out:
# 'Afghanistan'

# %%
ser[1702]
# Out:
# 'Zimbabwe'

# %% [markdown]
# ## Implicit & Explicit Indexing

# %%
ser1 = pd.Series([1, 5, 7, 9, 10])
ser1
# Out:
# 0     1
# 1     5
# 2     7
# 3     9
# 4    10
# dtype: int64

# %%
ser2 = pd.Series([1, 5, 7, 9, 10], index= ['a', 'b', 'c', 'd', 'e'])
ser2
# Out:
# a     1
# b     5
# c     7
# d     9
# e    10
# dtype: int64

# %%
ser2['b']
# Out:
# 5

# %%
ser2[1]
# Out:
# 5

# %%
ser2.loc['b']
# Out:
# 5

# %%
ser2.iloc[1]
# Out:
# 5

# %%
ser2.iloc[1:4]
# Out:
# b    5
# c    7
# d    9
# dtype: int64

# %%
ser2.iloc[1:-1]
# Out:
# b    5
# c    7
# d    9
# dtype: int64

# %%
ser2.loc['b':'e']
# Out:
# b     5
# c     7
# d     9
# e    10
# dtype: int64

# %%
ser2.loc[['b','e']]
# Out:
# b     5
# e    10
# dtype: int64

# %%
temp = df.set_index('country')
temp
# Out:
#              year  population  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# Zimbabwe     1987     9216418    62.351  706.157306
# Zimbabwe     1992    10704340    60.377  693.420786
# Zimbabwe     1997    11404948    46.809  792.449960
# Zimbabwe     2002    11926563    39.989  672.038623
# Zimbabwe     2007    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
temp.reset_index()
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp = df.set_index('country')
temp
temp.loc['Afghanistan']
# Out:
#              year  population  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# Afghanistan  1977    14880372    38.438  786.113360
# Afghanistan  1982    12881816    39.854  978.011439
# Afghanistan  1987    13867957    40.822  852.395945
# Afghanistan  1992    16317921    41.674  649.341395
# Afghanistan  1997    22227415    41.763  635.341351
# Afghanistan  2002    25268405    42.129  726.734055
# Afghanistan  2007    31889923    43.828  974.580338

# %% [markdown]
# ## Insert new row

# %%
dic = {'country': 'India', 'year': 2000, 'life_exp':37.08, 'population':131889923, 'gdp_cap':779.445314}

# %%
df.append(dic, ignore_index=True)
df
# Out:
# C:\Users\mthiru947\AppData\Local\Temp\ipykernel_16592\2977394586.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(dic, ignore_index=True)
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
pd.concat(df, pd.DataFrame(dic), axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 pd.concat(df, pd.DataFrame(dic), axis=0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...

# %% [markdown]
# ## Identifying duplicate

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Length: 1704, dtype: bool

# %%
df.drop_duplicates(subset='gdp_cap')
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
#  ## 2D Slicing

# %%
df.iloc[0:3, 0:3]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083

# %%
df.loc[0:2, 'country':'population']
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083

# %%
df.iloc[[10, 20, 30], [0, 2, -1]]
# Out:
#         country  population      gdp_cap
# 10  Afghanistan    25268405   726.734055
# 20      Albania     3326498  2497.437901
# 30      Algeria    20033753  5745.160213

# %%
df.iloc[[10, 20, 30], :][['country', 'population', 'gdp_cap']]
# Out:
#         country  population      gdp_cap
# 10  Afghanistan    25268405   726.734055
# 20      Albania     3326498  2497.437901
# 30      Algeria    20033753  5745.160213

# %%
df.iloc[-1:]
# Out:
#        country  year  population  life_exp     gdp_cap
# 1703  Zimbabwe  2007    12311143    43.487  469.709298

# %% [markdown]
# ## Practice

# %%
pd.DataFrame(df, columns=['life_exp', 'country', 'year'])
# Out:
#       life_exp      country  year
# 0       28.801  Afghanistan  1952
# 1       30.332  Afghanistan  1957
# 2       31.997  Afghanistan  1962
# 3       34.020  Afghanistan  1967
# 4       36.088  Afghanistan  1972
# ...        ...          ...   ...
# 1699    62.351     Zimbabwe  1987
# 1700    60.377     Zimbabwe  1992
# 1701    46.809     Zimbabwe  1997
# 1702    39.989     Zimbabwe  2002
# 1703    43.487     Zimbabwe  2007
#
# [1704 rows x 3 columns]

# %%
for x in df.columns:
    print(df[x].nunique())
    if df[x].nunique()==12:
        df.drop(x, axis=1, inplace=True)
# Out:
# 142
# 12
# 1704
# 1626
# 1704

# %%
df
# Out:
#           country  population  life_exp     gdp_cap
# 0     Afghanistan     8425333    28.801  779.445314
# 1     Afghanistan     9240934    30.332  820.853030
# 2     Afghanistan    10267083    31.997  853.100710
# 3     Afghanistan    11537966    34.020  836.197138
# 4     Afghanistan    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# 1699     Zimbabwe     9216418    62.351  706.157306
# 1700     Zimbabwe    10704340    60.377  693.420786
# 1701     Zimbabwe    11404948    46.809  792.449960
# 1702     Zimbabwe    11926563    39.989  672.038623
# 1703     Zimbabwe    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]
