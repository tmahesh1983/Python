# %%
import pandas as pd

# %%
def solve(reg_id, reg_dates):
    """
    Complete the function to return a Pandas Dataframe object as per the description.
    """
    df=None
    # YOUR CODE GOES HERE
    df = pd.DataFrame({'RID':reg_id, 'RDate':reg_dates})
    
    return df

# %%
# df = pd.read_html("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/716/original/sales_dataset.csv")
sales_df = pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/716/original/sales_dataset.csv")
sales_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                      ...    ...          ...             ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %% [markdown]
# ## Highest sales date in France

# %%
sales_df['sales_price'] = sales_df['Quantity'] * sales_df['Price']
sales_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.40
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.80
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.00
# ...                      ...    ...          ...             ...          ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France        12.60
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France        14.85
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France        18.00
#
# [1067371 rows x 9 columns]

# %%
sales_df_group = sales_df.groupby(['Country', 'InvoiceDate']).sum()['sales_price']
# sales_df_group.get_group('Country')
# sales_df_group = sales_df.groupby(['Country', 'InvoiceDate']).sum()[sales_df['Country'] == 'France']
# sales_df_group = [sales_df_group['Country'] == 'Australia']
sales_data_frame = sales_df_group.to_frame().reset_index()
sales_data_frame = sales_data_frame[sales_data_frame['Country'] == 'France']
sales_data_frame
# Out:
#      Country          InvoiceDate  sales_price
# 1428  France  2009-12-01 09:28:00       426.30
# 1429  France  2009-12-01 12:09:00        -5.95
# 1430  France  2009-12-01 12:52:00       603.94
# 1431  France  2009-12-02 10:28:00       -28.95
# 1432  France  2009-12-02 16:24:00       578.28
# ...      ...                  ...          ...
# 2168  France  2011-12-07 08:07:00       694.77
# 2169  France  2011-12-07 15:02:00       422.85
# 2170  France  2011-12-08 11:35:00       165.90
# 2171  France  2011-12-08 11:46:00       -19.20
# 2172  France  2011-12-09 12:50:00       267.45
#
# [745 rows x 3 columns]

# %%
sales_data_frame.columns
# Out:
# Index(['Country', 'InvoiceDate', 'sales_price'], dtype='object')

# %%
sales_data_frame[sales_data_frame['sales_price'] == sales_data_frame['sales_price'].max()]
# Out:
#      Country          InvoiceDate  sales_price
# 1588  France  2010-08-09 13:10:00     11880.84

# %% [markdown]
# ## Highest Amount Purchase

# %%
sales_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.40
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.80
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.00
# ...                      ...    ...          ...             ...          ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France        12.60
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France        14.85
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France        18.00
#
# [1067371 rows x 9 columns]

# %%
sales_df['sales_price'] = sales_df['Quantity'] * sales_df['Price']
sales_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.40
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.80
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.00
# ...                      ...    ...          ...             ...          ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France        12.60
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France        14.85
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France        18.00
#
# [1067371 rows x 9 columns]

# %%
sales_df[sales_df['sales_price'] == sales_df['sales_price'].max()]
# Out:
#         Invoice StockCode                  Description  Quantity  \
# 1065882  581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price
# 1065882  2011-12-09 09:15:00   2.08      16446.0  United Kingdom     168469.6

# %% [markdown]
# ##  Number of customers

# %%
sales_df[sales_df['Country'] == 'United Kingdom']
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067350  581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 1067351  581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 1067352  581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 1067353  581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 1067354  581586     20685                DOORMAT RED RETROSPOT        10
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom         83.4
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom        100.8
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom         30.0
# ...                      ...    ...          ...             ...          ...
# 1067350  2011-12-09 12:31:00   1.95      15804.0  United Kingdom         23.4
# 1067351  2011-12-09 12:49:00   2.95      13113.0  United Kingdom         23.6
# 1067352  2011-12-09 12:49:00   1.25      13113.0  United Kingdom         30.0
# 1067353  2011-12-09 12:49:00   8.95      13113.0  United Kingdom        214.8
# 1067354  2011-12-09 12:49:00   7.08      13113.0  United Kingdom         70.8
#
# [981330 rows x 9 columns]

# %%
sales_df.StockCode.unique().
# Out:
# 85123A       5829
# 22423        4424
# 85099B       4216
# 21212        3318
# 20725        3259
#              ...
# DCGS0067        1
# DCGS0066P       1
# DCGS0071        1
# DCGS0073        1
# 90197A          1
# Name: StockCode, Length: 5305, dtype: int64

# %%
sales_df.nunique()
# Out:
# Invoice        53628
# StockCode       5305
# Description     5698
# Quantity        1057
# InvoiceDate    47635
# Price           2807
# Customer ID     5942
# Country           43
# sales_price     9113
# dtype: int64

# %%
sales_df['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     5918
# REGENCY CAKESTAND 3 TIER               4412
# JUMBO BAG RED RETROSPOT                3469
# ASSORTED COLOUR BIRD ORNAMENT          2958
# PARTY BUNTING                          2765
#                                        ...
# IVORY PENDANT SHELL NECKLACE              1
# allocate stock for dotcom orders ta       1
# PAINTED HEART WREATH WITH BELL            1
# FLOWER FAIRY MUG+COASTER,ROSE             1
# Zebra invcing error                       1
# Name: Description, Length: 5698, dtype: int64

# %%
sales_df.groupby('Description').sum()['Quantity'].sort_values()
# Out:
# Description
# ?                                     -26757
# given away                            -20000
# printing smudges/thrown away          -19200
# missing                               -16467
# Unsaleable, destroyed.                -15644
#                                        ...
# BROCADE RING PURSE                     70700
# JUMBO BAG RED RETROSPOT                78090
# ASSORTED COLOUR BIRD ORNAMENT          81306
# WHITE HANGING HEART T-LIGHT HOLDER     93050
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545
# Name: Quantity, Length: 5698, dtype: int64

# %% [markdown]
# ## Number of customers

# %%
sales_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.40
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.80
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.00
# ...                      ...    ...          ...             ...          ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France        12.60
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France        14.85
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France        18.00
#
# [1067371 rows x 9 columns]

# %%
sales_df['date'] = pd.to_datetime(df['InvoiceDate'], errors='coerce').dt.date
sales_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  sales_price  \
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.40
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.00
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.80
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.00
# ...                      ...    ...          ...             ...          ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France        12.60
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France        16.60
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France        14.85
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France        18.00
#
#                date
# 0        2009-12-01
# 1        2009-12-01
# 2        2009-12-01
# 3        2009-12-01
# 4        2009-12-01
# ...             ...
# 1067366  2011-12-09
# 1067367  2011-12-09
# 1067368  2011-12-09
# 1067369  2011-12-09
# 1067370  2011-12-09
#
# [1067371 rows x 10 columns]

# %%
 sales_df[sales_df['date'] == pd.to_datetime('2011-06-22')].nunique()
# Out:
# C:\Users\mthiru947\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
# Invoice         68
# StockCode      652
# Description    649
# Quantity        47
# InvoiceDate     63
# Price           76
# Customer ID     57
# Country          8
# sales_price    278
# date             1
# dtype: int64

# %%
type(sales_df['date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Get the Month

# %%
# 498 721 375 464 813 853
# 2015-12-06 2011-12-27 2015-09-07 2012-12-21 2020-02-13 2015-06-09

# %%
import pandas as pd
def solve(reg_id, reg_dates):
    """
    Complete the function to return a Pandas Dataframe object as per the description.
    """
    df=None
    # YOUR CODE GOES HERE
    df = pd.DataFrame({'RID':reg_id, 'RDate':reg_dates})
    df['RMonth'] = pd.to_datetime(df['RDate']).dt.month
    df['RMonth'] = df.apply(lambda x: f"{x['Phy']:02d}", axis=1)
    df['RMonth'] = df['RMonth']
    df['RYear'] = pd.to_datetime(df['RDate']).dt.year
    df['RDay'] = pd.to_datetime(df['RDate']).dt.day    
    return df

# %%
# rid = [498, 721, 375, 464, 813, 853]
# rdates = ['2015-12-06', '2011-12-27', '2015-09-07', '2012-12-21', '2020-02-13', '2015-06-09']

rid = [498, 721, 375, 464, 813, 853]
rdates = ['2015-12-06', '2011-12-27', '2015-09-07', '2012-12-21', '2020-02-13', '2015-06-09']
solve(rid, rdates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [149], in <cell line: 6>()
#       4 rid = [498, 721, 375, 464, 813, 853]
#       5 rdates = ['2015-12-06', '2011-12-27', '2015-09-07', '2012-12-21', '2020-02-13', '2015-06-09']
# ----> 6 solve(rid, rdates)
#
# Input In [148], in solve(reg_id, reg_dates)
#       8 df = pd.DataFrame({'RID':reg_id, 'RDate':reg_dates})
#       9 df['RMonth'] = pd.to_datetime(df['RDate']).dt.month
# ---> 10 df['RMonth'] = df.to_string(columns=['RMonth'], formatters={'RMonth':'02d'})
#      11 df['RYear'] = pd.to_datetime(df['RDate']).dt.year
#      12 df['RDay'] = pd.to_datetime(df['RDate']).dt.day
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1192, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1173 with option_context("display.max_colwidth", max_colwidth):
#    1174     formatter = fmt.DataFrameFormatter(
#    1175         self,
#    1176         columns=columns,
#    (...)
#    1190         decimal=decimal,
#    1191     )
# -> 1192     return fmt.DataFrameRenderer(formatter).to_string(
#    1193         buf=buf,
#    1194         encoding=encoding,
#    1195         line_width=line_width,
#    1196     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1128, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1125 from pandas.io.formats.string import StringFormatter
#    1127 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1128 string = string_formatter.to_string()
#    1129 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\string.py:25, in StringFormatter.to_string(self)
#      24 def to_string(self) -> str:
# ---> 25     text = self._get_string_representation()
#      26     if self.fmt.should_show_dimensions:
#      27         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\string.py:40, in StringFormatter._get_string_representation(self)
#      37 if self.fmt.frame.empty:
#      38     return self._empty_info_line
# ---> 40 strcols = self._get_strcols()
#      42 if self.line_width is None:
#      43     # no need to wrap around just print the whole frame
#      44     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\string.py:31, in StringFormatter._get_strcols(self)
#      30 def _get_strcols(self) -> list[list[str]]:
# ---> 31     strcols = self.fmt.get_strcols()
#      32     if self.fmt.is_truncated:
#      33         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:611, in DataFrameFormatter.get_strcols(self)
#     607 def get_strcols(self) -> list[list[str]]:
#     608     """
#     609     Render a DataFrame to a list of columns (as lists of strings).
#     610     """
# --> 611     strcols = self._get_strcols_without_index()
#     613     if self.index:
#     614         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:875, in DataFrameFormatter._get_strcols_without_index(self)
#     871 cheader = str_columns[i]
#     872 header_colwidth = max(
#     873     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     874 )
# --> 875 fmt_values = self.format_col(i)
#     876 fmt_values = _make_fixed_width(
#     877     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     878 )
#     880 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:889, in DataFrameFormatter.format_col(self, i)
#     887 frame = self.tr_frame
#     888 formatter = self._get_formatter(i)
# --> 889 return format_array(
#     890     frame.iloc[:, i]._values,
#     891     formatter,
#     892     float_format=self.float_format,
#     893     na_rep=self.na_rep,
#     894     space=self.col_space.get(frame.columns[i]),
#     895     decimal=self.decimal,
#     896     leading_space=self.index,
#     897 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1316, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1301     digits = get_option("display.precision")
#    1303 fmt_obj = fmt_klass(
#    1304     values,
#    1305     digits=digits,
#    (...)
#    1313     quoting=quoting,
#    1314 )
# -> 1316 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1347, in GenericArrayFormatter.get_result(self)
#    1346 def get_result(self) -> list[str]:
# -> 1347     fmt_values = self._format_strings()
#    1348     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1604, in IntArrayFormatter._format_strings(self)
#    1602     formatter_str = lambda x: f"{x: d}".format(x=x)
#    1603 formatter = self.formatter or formatter_str
# -> 1604 fmt_values = [formatter(x) for x in self.values]
#    1605 return fmt_values
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1604, in <listcomp>(.0)
#    1602     formatter_str = lambda x: f"{x: d}".format(x=x)
#    1603 formatter = self.formatter or formatter_str
# -> 1604 fmt_values = [formatter(x) for x in self.values]
#    1605 return fmt_values
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## Max registrations they asked?

# %%
student_df = pd.DataFrame({'Date':["2015-12-06", "2011-12-27", "2015-09-07", "2012-12-21", "2020-02-13", "2015-06-09"], 'RID':[498, 721, 375, 464, 813, 853], 'Phy':[22, 45, 1, 65, 22, 17], 'Chem':[52, 56, 32, 50, 24, 61], 'Math':[63, 37, 68, 62, 43 ,42]}) 


student_df['Phy'] = df.apply(lambda x: f"{x['Phy']:02d}", axis=1)
student_df
# Out:
#          Date  RID Phy  Chem  Math
# 0  2015-12-06  498  22    52    63
# 1  2011-12-27  721  45    56    37
# 2  2015-09-07  375  01    32    68
# 3  2012-12-21  464  65    50    62
# 4  2020-02-13  813  22    24    43
# 5  2015-06-09  853  17    61    42

# %%
student_df['Month'] = pd.to_datetime(student_df['Date']).dt.month
student_df
# Out:
#          Date  RID  Phy  Chem  Math  Month
# 0  2015-12-06  498   22    52    63     12
# 1  2011-12-27  721   45    56    37     12
# 2  2015-09-07  375    1    32    68      9
# 3  2012-12-21  464   65    50    62     12
# 4  2020-02-13  813   22    24    43      2
# 5  2015-06-09  853   17    61    42      6

# %%
max_occur_month = student_df['Month'].mode()
print(type(max_occur_month))
max_reg_mnth_stud_df = student_df[pd.to_datetime(student_df['Month']) == student_df['Month'].mode()]
# max_reg_mnth_stud_df
# Out:
# <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [138], in <cell line: 3>()
#       1 max_occur_month = student_df['Month'].mode()
#       2 print(type(max_occur_month))
# ----> 3 max_reg_mnth_stud_df = student_df[pd.to_datetime(student_df['Month']) == student_df['Month'].mode()]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:5617, in Series._cmp_method(self, other, op)
#    5614 res_name = ops.get_op_result_name(self, other)
#    5616 if isinstance(other, Series) and not self._indexed_same(other):
# -> 5617     raise ValueError("Can only compare identically-labeled Series objects")
#    5619 lvalues = self._values
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
import pandas as pd
import numpy as np
def solve(df):
    """
    input: pandas dataframe with columns ['Date', 'R_id', 'Phy', 'Chem', 'Math']
    output: pandas series
    """
    
    # code for taking input and printing output is already taken care of just return the list with required elements.
    """
        You need to return a series where the elements will be the most occuring month,
        most occuring month's frequency, average chemistry,physics and maths marks in 
        most occuring months upto two decimal places in this order.
    """
    # YOUR CODE GOES HERE
    
    
    # YOUR CODE ENDS HERE
    return pd.Series([])
